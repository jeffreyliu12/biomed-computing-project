# %%
import pandas as pd
import zipfile

# %%
vax_percent_df = pd.read_csv("County - Table_data.csv")

percent_ovr_65_df = pd.read_csv("Pop over 65%.csv",skiprows=4)

with zipfile.ZipFile('AHRF_CSV_2022-2023.zip', 'r') as z:
    with z.open('AHRF_CSV_2022-2023/DATA/ahrf2023.csv') as f:
        ahrf_df = pd.read_csv(f, encoding='latin1', low_memory=False)

# %%
vax_percent_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Jurisdiction    714 non-null    str
#  1   Measure Names   714 non-null    str
#  2   Measure Values  712 non-null    float64
# dtypes: float64(1), str(2)
# memory usage: 16.9 KB

# %%
unique_measures = vax_percent_df['Measure Names'].unique()
print(unique_measures)
# Out:
# <StringArray>
# [                    '7-Day Doses Administered',
#  'Percent of Population Completing Vaccination',
#  'Percent of Population Initiating Vaccination',
#            'COVID-19 Vaccine Regimen Completed',
#            'COVID-19 Vaccine Regimen Initiated',
#                      'Total Doses Administered']
# Length: 6, dtype: str

# %%
completing_measure = ['Percent of Population Completing Vaccination']
vax_percent_complete_df = vax_percent_df[vax_percent_df['Measure Names'].isin(completing_measure)].copy()

# %%
vax_percent_complete_df = (vax_percent_complete_df.drop(columns=['Measure Names']).rename(columns = {'Measure Values': 'Percent of Population Completing Vaccination'}).reset_index(drop=True))

# %%
vax_percent_complete_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 2 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Jurisdiction                                  119 non-null    str
#  1   Percent of Population Completing Vaccination  118 non-null    float64
# dtypes: float64(1), str(1)
# memory usage: 2.0 KB

# %%
unique_measures = vax_percent_complete_df['Jurisdiction'].unique()
print(unique_measures)
# Out:
# <StringArray>
# [              'Wright',                'Worth',              'Webster',
#                 'Wayne',           'Washington',               'Warren',
#                'Vernon', 'Unknown Jurisdiction',                'Texas',
#                 'Taney',
#  ...
#                 'Boone',            'Bollinger',               'Benton',
#                 'Bates',               'Barton',                'Barry',
#               'Audrain',             'Atchison',               'Andrew',
#                 'Adair']
# Length: 119, dtype: str

# %%
vax_complete_cleaned = vax_percent_complete_df.dropna()
vax_complete_cleaned.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 118 entries, 0 to 118
# Data columns (total 2 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Jurisdiction                                  118 non-null    str
#  1   Percent of Population Completing Vaccination  118 non-null    float64
# dtypes: float64(1), str(1)
# memory usage: 2.8 KB

# %%
vax_complete_cleaned
# Out:
#     Jurisdiction  Percent of Population Completing Vaccination
# 0         Wright                                      0.375800
# 1          Worth                                      0.401391
# 2        Webster                                      0.413594
# 3          Wayne                                      0.320360
# 4     Washington                                      0.361868
# ..           ...                                           ...
# 114        Barry                                      0.416972
# 115      Audrain                                      0.405034
# 116     Atchison                                      0.580789
# 117       Andrew                                      0.478884
# 118        Adair                                      0.495285
#
# [118 rows x 2 columns]

# %%
initiating_measure = ['Percent of Population Initiating Vaccination']
vax_percent_initiate_df = vax_percent_df[vax_percent_df['Measure Names'].isin(initiating_measure)].copy()

# %%
vax_percent_initiate_df = (vax_percent_initiate_df.drop(columns=['Measure Names']).rename(columns = {'Measure Values': 'Percent of Population Initiating Vaccination'}).reset_index(drop=True))

# %%
vax_percent_initiate_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 2 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Jurisdiction                                  119 non-null    str
#  1   Percent of Population Initiating Vaccination  118 non-null    float64
# dtypes: float64(1), str(1)
# memory usage: 2.0 KB

# %%
unique_measures = vax_percent_initiate_df['Jurisdiction'].unique()
print(unique_measures)
# Out:
# <StringArray>
# [              'Wright',                'Worth',              'Webster',
#                 'Wayne',           'Washington',               'Warren',
#                'Vernon', 'Unknown Jurisdiction',                'Texas',
#                 'Taney',
#  ...
#                 'Boone',            'Bollinger',               'Benton',
#                 'Bates',               'Barton',                'Barry',
#               'Audrain',             'Atchison',               'Andrew',
#                 'Adair']
# Length: 119, dtype: str

# %%
vax_initiate_cleaned = vax_percent_initiate_df.dropna()
vax_initiate_cleaned.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 118 entries, 0 to 118
# Data columns (total 2 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Jurisdiction                                  118 non-null    str
#  1   Percent of Population Initiating Vaccination  118 non-null    float64
# dtypes: float64(1), str(1)
# memory usage: 2.8 KB

# %%
vax_initiate_cleaned
# Out:
#     Jurisdiction  Percent of Population Initiating Vaccination
# 0         Wright                                      0.409208
# 1          Worth                                      0.433184
# 2        Webster                                      0.444913
# 3          Wayne                                      0.350113
# 4     Washington                                      0.397816
# ..           ...                                           ...
# 114        Barry                                      0.464752
# 115      Audrain                                      0.450173
# 116     Atchison                                      0.597317
# 117       Andrew                                      0.495314
# 118        Adair                                      0.527009
#
# [118 rows x 2 columns]

# %%
ahrf_df
# Out:
#       blank  fips_st_cnty entity_file  secndry_entity_file  date_file  \
# 0       NaN          1001        AHRF                 1001       2023
# 1       NaN          1003        AHRF                 1003       2023
# 2       NaN          1005        AHRF                 1005       2023
# 3       NaN          1007        AHRF                 1007       2023
# 4       NaN          1009        AHRF                 1009       2023
# ...     ...           ...         ...                  ...        ...
# 3226    NaN         72151        AHRF                72151       2023
# 3227    NaN         72153        AHRF                72153       2023
# 3228    NaN         78010        AHRF                78010       2023
# 3229    NaN         78020        AHRF                78020       2023
# 3230    NaN         78030        AHRF                78030       2023
#
#       date_cretn  file_length            st_name st_name_abbrev   cnty_name  \
# ...

# %%
ahrf_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3231 entries, 0 to 3230
# Columns: 4306 entries, blank to elevtn_feet_76
# dtypes: float64(4286), int64(9), str(11)
# memory usage: 106.1 MB

# %%
ahrf_df.columns.tolist()
# Out:
# ['blank',
#  'fips_st_cnty',
#  'entity_file',
#  'secndry_entity_file',
#  'date_file',
#  'date_cretn',
#  'file_length',
#  'st_name',
#  'st_name_abbrev',
#  'cnty_name',
#  'cnty_name_st_abbrev',
#  'fips_st',
#  'fips_cnty',
#  'cens_regn',
#  'cens_regn_name',
#  'cens_divsn',
#  'cens_divsn_name',
#  'fed_regn',
#  'ssa_benfcry',
#  'cbsa_20',
#  'cbsa_name_20',
#  'cbsa_ind_20',
#  'cbsa_cnty_stats_20',
#  'metro_divsn_20',
#  'metro_divsn_name_20',
#  'combnd_stat_area_20',
#  'combnd_stat_area_name_20',
#  'rural_urban_contnm_13',
#  'urban_influnc_13',
#  'econ_depndnt_typolgy_15',
#  'farmng_depndnt_typolgy_15',
#  'minng_depndnt_typolgy_15',
#  'mfg_depndnt_typolgy_15',
#  'fed_st_govt_depndnt_typolgy_15',
#  'recrtn_typolgy_15',
#  'nonspclzd_depndnt_typolgy_15',
#  'lo_eductn_typolgy_15',
#  'lo_emplymt_typolgy_15',
#  'hi_povty_typolgy_14',
#  'prstnt_povty_typolgy_14',
#  'prstnt_child_povty_typolgy_15',
#  'popn_loss_typolgy_15',
#  'retrmnt_destntn_typolgy_15',
# ...

# %%
mo_county_population = pd.read_csv("co-est2024-pop-29.csv", header=2, skipfooter = 6, engine='python')

mo_county_population = mo_county_population.rename(columns={
    'Population Estimate (as of July 1)': '2020 Population Estimate',
    'Unnamed: 3': '2021 Population Estimate',
    'Unnamed: 4': '2022 Population Estimate',
    'Unnamed: 5': '2023 Population Estimate',
    'Unnamed: 6': '2024 Population Estimate'
})

mo_county_population = mo_county_population.drop(0)

mo_county_population['Geographic Area'] = mo_county_population['Geographic Area'].str.replace('.', '', regex=False)
mo_county_population['Geographic Area'] = mo_county_population['Geographic Area'].str.replace(', Missouri', '', regex=False)
mo_county_population['Geographic Area'] = mo_county_population['Geographic Area'].str.replace(' County', '', regex=False).str.upper()
mo_county_population = mo_county_population.loc[:, ~mo_county_population.columns.str.contains('^Unnamed')]
mo_county_population = mo_county_population[mo_county_population['Geographic Area'] != 'MISSOURI']

mo_county_population = mo_county_population.reset_index(drop=True)

mo_county_population = mo_county_population[['Geographic Area', '2021 Population Estimate']]

mo_county_population
# Out:
#     Geographic Area 2021 Population Estimate
# 0             ADAIR                   25,188
# 1            ANDREW                   18,015
# 2          ATCHISON                    5,210
# 3           AUDRAIN                   24,858
# 4             BARRY                   34,762
# ..              ...                      ...
# 110           WAYNE                   10,925
# 111         WEBSTER                   39,600
# 112           WORTH                    1,973
# 113          WRIGHT                   18,625
# 114   ST LOUIS CITY                  293,484
#
# [115 rows x 2 columns]

# %%
columns_to_keep = [
    'st_name_abbrev', 
    'cnty_name', 
    'phys_nf_prim_care_pc_exc_rsdt_21', 
]

pcp_df = ahrf_df[columns_to_keep].copy()

mo_pcp_df = pcp_df[pcp_df['st_name_abbrev'] == 'MO'].copy()
mo_pcp_df['cnty_name'] = mo_pcp_df['cnty_name'].str.upper()

merged_df = pd.merge(
    mo_pcp_df, 
    mo_county_population, 
    left_on='cnty_name', 
    right_on='Geographic Area', 
    how='inner'
)

merged_df = merged_df.drop(columns=['Geographic Area'])
merged_df = merged_df.drop(columns=['st_name_abbrev'])

merged_df = merged_df.rename(columns={
    'cnty_name': 'County',
    'phys_nf_prim_care_pc_exc_rsdt_21': 'Number of primary care providers'
})

merged_df['2021 Population Estimate'] = merged_df['2021 Population Estimate'].str.replace(',', '', regex=False)
merged_df['2021 Population Estimate'] = pd.to_numeric(merged_df['2021 Population Estimate'])

merged_df['primary care providers per 100k'] = (merged_df['Number of primary care providers'] / merged_df['2021 Population Estimate']) * 100000

# %%
merged_df.sort_values(by='primary care providers per 100k', ascending=False)
# Out:
#       County  Number of primary care providers  2021 Population Estimate  \
# 0      ADAIR                              44.0                     25188
# 93  SCOTLAND                               8.0                      4674
# 9      BOONE                             220.0                    186132
# 63    MARION                              29.0                     28564
# 11    BUTLER                              40.0                     42163
# ..       ...                               ...                       ...
# 27  CRAWFORD                               1.0                     22826
# 51      KNOX                               0.0                      3786
# 74    OREGON                               0.0                      8628
# 43      HOLT                               0.0                      4234
# 62    MARIES                               0.0                      8418
#
#     primary care providers per 100k
# 0                        174.686359
# ...

# %%
percent_ovr_65_df
# Out:
#                                                 County     FIPS  \
# 0                                        United States      0.0
# 1                                             Missouri  29000.0
# 2                                       Pulaski County  29169.0
# 3                                       Johnson County  29101.0
# 4                                         Boone County  29019.0
# ..                                                 ...      ...
# 118  HDPulse: An Ecosystem of Minority Health and H...      NaN
# 119                                             Notes:      NaN
# 120  NA: Data not available [http://hdpulse.nimhd.n...      NaN
# 121  Source: Demographic data provided by the Censu...      NaN
# 122  For more information about Population (Age 65 ...      NaN
#
#      Value (Percent)  People (Age 65 And Over)  \
# 0               16.8                55970047.0
# 1               17.5                 1079129.0
# 2                9.6                    5169.0
# ...

# %%
percent_ovr_65_df.columns
# Out:
# Index(['County', 'FIPS', 'Value (Percent)', 'People (Age 65 And Over)',
#        'Rank within US (of 3143 counties)'],
#       dtype='str')

# %%
percent_ovr_65_value_df = percent_ovr_65_df[['County', 'Value (Percent)']].copy()
percent_ovr_65_value_df = percent_ovr_65_value_df.rename(columns={
    'Value (Percent)': 'Percent of population over 65'
})
percent_ovr_65_value_df
# Out:
#                                                 County  \
# 0                                        United States
# 1                                             Missouri
# 2                                       Pulaski County
# 3                                       Johnson County
# 4                                         Boone County
# ..                                                 ...
# 118  HDPulse: An Ecosystem of Minority Health and H...
# 119                                             Notes:
# 120  NA: Data not available [http://hdpulse.nimhd.n...
# 121  Source: Demographic data provided by the Censu...
# 122  For more information about Population (Age 65 ...
#
#      Percent of population over 65
# 0                             16.8
# 1                             17.5
# 2                              9.6
# 3                             12.9
# 4                             13.1
# ..                             ...
# 118                            NaN
# ...

# %%
percent_ovr_65_value_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   County                         123 non-null    str
#  1   Percent of population over 65  117 non-null    float64
# dtypes: float64(1), str(1)
# memory usage: 2.1 KB

# %%
unique_percents = percent_ovr_65_value_df['Percent of population over 65'].unique()
print(unique_percents)
# Out:
# [16.8 17.5  9.6 12.9 13.1 14.3 14.9 15.2 15.5 15.7 15.8 16.1 16.3 16.4
#  16.9 17.1 17.2 17.3 17.4 17.8 17.9 18.  18.1 18.3 18.4 18.5 18.6 18.7
#  18.8 18.9 19.  19.1 19.2 19.3 19.5 19.6 19.8 19.9 20.  20.1 20.2 20.4
#  20.5 20.6 20.7 20.8 20.9 21.  21.2 21.7 21.8 21.9 22.  22.2 22.3 22.4
#  22.6 22.8 22.9 23.3 23.6 24.3 24.5 24.7 25.  25.1 25.2 25.6 25.8 28.9
#  29.  31.1 31.3 32.4  nan]

# %%
percent_ovr_65_cleaned = percent_ovr_65_value_df.dropna()

# %%
percent_ovr_65_value_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   County                         123 non-null    str
#  1   Percent of population over 65  117 non-null    float64
# dtypes: float64(1), str(1)
# memory usage: 2.1 KB

# %%
percent_ovr_65_cleaned.sort_values(by='Percent of population over 65', ascending=False)
# Out:
#              County  Percent of population over 65
# 116  Hickory County                           32.4
# 115    Stone County                           31.3
# 114   Benton County                           31.1
# 113    Ozark County                           29.0
# 112   Camden County                           28.9
# ..              ...                            ...
# 6       Clay County                           14.9
# 5    Lincoln County                           14.3
# 4      Boone County                           13.1
# 3    Johnson County                           12.9
# 2    Pulaski County                            9.6
#
# [117 rows x 2 columns]

# %%
master_df = pd.read_csv('missouri_counties_covid_and_economic_data_2022.csv')
master_df
# Out:
#             County  County FIPS Code  2022 Covid Infections  \
# 0         ST LOUIS           29189.0                 124171
# 1          JACKSON           29095.0                  79621
# 2       ST CHARLES           29183.0                  48803
# 3           GREENE           29077.0                  33739
# 4    ST LOUIS CITY           29510.0                  32679
# 5             CLAY           29047.0                  28200
# 6        JEFFERSON           29099.0                  26023
# 7            BOONE           29019.0                  23705
# 8           JASPER           29097.0                  14283
# 9             CASS           29037.0                  11391
# 10        FRANKLIN           29071.0                  10984
# 11        BUCHANAN           29021.0                  10902
# 12          PLATTE           29165.0                  10896
# 13       CHRISTIAN           29043.0                   9324
# 14     ST FRANCOIS           29187.0                   8856
# ...

# %%
mo_pcp_df = pcp_df[pcp_df['st_name_abbrev'] == 'MO'].copy()
mo_pcp_df['cnty_name'] = mo_pcp_df['cnty_name'].str.upper().str.replace('.', '', regex=False)

mo_pcp_df['cnty_name'] = mo_pcp_df['cnty_name'].str.replace('ST LOUIS (INDEPENDENT CITY)', 'ST LOUIS CITY', regex=False)

merged_df = pd.merge(mo_pcp_df, mo_county_population, left_on='cnty_name', right_on='Geographic Area', how='inner')
merged_df = merged_df.drop(columns=['Geographic Area', 'st_name_abbrev'])
merged_df = merged_df.rename(columns={'cnty_name': 'County', 'phys_nf_prim_care_pc_exc_rsdt_21': 'Number of primary care providers'})
merged_df['2021 Population Estimate'] = pd.to_numeric(merged_df['2021 Population Estimate'].str.replace(',', '', regex=False))
merged_df['primary care providers per 100k'] = (merged_df['Number of primary care providers'] / merged_df['2021 Population Estimate']) * 100000

pcp_subset = merged_df[['County', 'Number of primary care providers', 'primary care providers per 100k']].copy()

final_merged_df = (master_df
                   .merge(percent_ovr_65_cleaned, on='County', how='inner')
                   .merge(vax_complete_cleaned, on='County', how='inner')
                   .merge(pcp_subset, on='County', how='inner'))

# %%
final_merged_df
# Out:
#             County  County FIPS Code  2022 Covid Infections  \
# 0         ST LOUIS           29189.0                 124171
# 1          JACKSON           29095.0                  79621
# 2       ST CHARLES           29183.0                  48803
# 3           GREENE           29077.0                  33739
# 4    ST LOUIS CITY           29510.0                  32679
# 5             CLAY           29047.0                  28200
# 6        JEFFERSON           29099.0                  26023
# 7            BOONE           29019.0                  23705
# 8           JASPER           29097.0                  14283
# 9             CASS           29037.0                  11391
# 10        FRANKLIN           29071.0                  10984
# 11        BUCHANAN           29021.0                  10902
# 12          PLATTE           29165.0                  10896
# 13       CHRISTIAN           29043.0                   9324
# 14     ST FRANCOIS           29187.0                   8856
# ...

# %%
final_merged_df.to_csv('final_df', index=False)
